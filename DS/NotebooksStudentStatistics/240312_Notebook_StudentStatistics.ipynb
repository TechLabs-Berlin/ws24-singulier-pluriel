# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/TechLabs/01_Introduction\ to\ Python\ Programming
# Out:
# /content/drive/MyDrive/TechLabs/01_Introduction to Python Programming

# %%
import numpy as np
import pandas as pd
import random
import plotly.express as px

# %%
df = pd.read_excel('data/240312_Techlabs_Students_total.xlsx')

# %%
df
# Out:
#      id       name gender  age   teacher      course level  points pass_fail
# 0     1     Oliver      m   22  teacher1      polish    C2      47      fail
# 1     3      Silas      m   41  teacher3     italian    A2      62      fail
# 2     5  Sebastian      m   21  teacher2      german    C2      46      fail
# 3     7     Austin      m   43  teacher1      polish    C2      65      fail
# 4     9     Jasper      m   26  teacher2      german    B1      47      fail
# ..  ...        ...    ...  ...       ...         ...   ...     ...       ...
# 95   92       Luna      f   39  teacher3  portuguese    B1      52      fail
# 96   94      Amara      f   32  teacher3     spanish    C2      70      pass
# 97   96      Clara      f   47  teacher1       czech    C2      62      fail
# 98   98    Paisley      f   24  teacher3  portuguese    A1      47      fail
# 99  100       Lucy      f   46  teacher2       dutch    B1      90      pass
#
# [100 rows x 9 columns]

# %%
data_courses = px.bar(df, x="course", color="course")
data_courses
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data_teacher3 = df.query("teacher == 'teacher3'")

# %%
# data_teacher3_pass = df.query("pass_fail == 'pass'")
# data_teacher3_fail = df.query("pass_fail == 'fail'")

# %%
data_teacher3_pass_fail_bar = px.bar(data_teacher3, y="course", color="pass_fail")
data_teacher3_pass_fail_bar
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data_teacher3_level_bar = px.bar(data_teacher3, x="course", color="level")
data_teacher3_level_bar
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# data_teacher_points_average = df.groupby(['teacher', 'points']).mean()
